# %%
pip install numpy pandas
# Out:
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (2.0.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (2.2.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas) (2026.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %%
import pandas as pd

# Load datasets
df_2022 = pd.read_csv("ipl_2022_deliveries.csv")
df_2023 = pd.read_csv("ipl_2023_deliveries.csv")
df_2024 = pd.read_csv("ipl_2024_deliveries.csv")
df_2025 = pd.read_csv("ipl_2025_deliveries.csv")
df_2026 = pd.read_csv("ipl_2026_deliveries.csv")

# Display first few rows
print(df_2022.head())
# Load datasets
df_2022 = pd.read_csv("/content/ipl_2022_deliveries.csv")
df_2023 = pd.read_csv("/content/ipl_2023_deliveries.csv")
df_2024 = pd.read_csv("/content/ipl_2024_deliveries.csv")
df_2025 = pd.read_csv("/content/ipl_2025_deliveries.csv")
df_2026 = pd.read_csv("/content/ipl_2026_deliveries.csv")

# Display first few rows
print(df_2022.head())
# Out:
#    match_id  season  match_no          date                     venue  \
# 0    202201    2022         1  Mar 26, 2022  Wankhede Stadium, Mumbai
# 1    202201    2022         1  Mar 26, 2022  Wankhede Stadium, Mumbai
# 2    202201    2022         1  Mar 26, 2022  Wankhede Stadium, Mumbai
# 3    202201    2022         1  Mar 26, 2022  Wankhede Stadium, Mumbai
# 4    202201    2022         1  Mar 26, 2022  Wankhede Stadium, Mumbai
#
#   batting_team bowling_team  innings  over  striker       bowler  runs_of_bat  \
# 0          CSK          KKR        1   0.1  Gaikwad  Umesh Yadav            0
# 1          CSK          KKR        1   0.1  Gaikwad  Umesh Yadav            0
# 2          CSK          KKR        1   0.2  Gaikwad  Umesh Yadav            0
# 3          CSK          KKR        1   0.2  Gaikwad  Umesh Yadav            0
# 4          CSK          KKR        1   0.3  Gaikwad  Umesh Yadav            0
#
#    extras  wide  legbyes  byes  noballs wicket_type player_dismissed  \
# 0       1     0        0     0        1         NaN              NaN
# 1       0     0        0     0        0         NaN              NaN
# 2       1     1        0     0        0         NaN              NaN
# 3       0     0        0     0        0         NaN              NaN
# 4       0     0        0     0        0      caught          Gaikwad
#
#        fielder
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4  Nitish Rana
#    match_id  season  match_no          date                     venue  \
# 0    202201    2022         1  Mar 26, 2022  Wankhede Stadium, Mumbai
# 1    202201    2022         1  Mar 26, 2022  Wankhede Stadium, Mumbai
# 2    202201    2022         1  Mar 26, 2022  Wankhede Stadium, Mumbai
# 3    202201    2022         1  Mar 26, 2022  Wankhede Stadium, Mumbai
# 4    202201    2022         1  Mar 26, 2022  Wankhede Stadium, Mumbai
#
#   batting_team bowling_team  innings  over  striker       bowler  runs_of_bat  \
# 0          CSK          KKR        1   0.1  Gaikwad  Umesh Yadav            0
# 1          CSK          KKR        1   0.1  Gaikwad  Umesh Yadav            0
# 2          CSK          KKR        1   0.2  Gaikwad  Umesh Yadav            0
# 3          CSK          KKR        1   0.2  Gaikwad  Umesh Yadav            0
# 4          CSK          KKR        1   0.3  Gaikwad  Umesh Yadav            0
#
#    extras  wide  legbyes  byes  noballs wicket_type player_dismissed  \
# 0       1     0        0     0        1         NaN              NaN
# 1       0     0        0     0        0         NaN              NaN
# 2       1     1        0     0        0         NaN              NaN
# 3       0     0        0     0        0         NaN              NaN
# 4       0     0        0     0        0      caught          Gaikwad
#
#        fielder
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4  Nitish Rana

# %%
df_all = pd.concat([df_2022, df_2023, df_2024, df_2025, df_2026])

print("Total rows:", df_all.shape)
# Out:
# Total rows: (78021, 21)

# %%
print(df_all.info())      # Data types
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 78021 entries, 0 to 8423
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   match_id          78021 non-null  int64
#  1   season            78021 non-null  int64
#  2   match_no          78021 non-null  int64
#  3   date              78021 non-null  object
#  4   venue             78021 non-null  object
#  5   batting_team      78021 non-null  object
#  6   bowling_team      78021 non-null  object
#  7   innings           78021 non-null  int64
#  8   over              78021 non-null  float64
#  9   striker           78021 non-null  object
#  10  bowler            78021 non-null  object
#  11  runs_of_bat       78021 non-null  int64
#  12  extras            78021 non-null  int64
#  13  wide              78021 non-null  int64
#  14  legbyes           78021 non-null  int64
#  15  byes              78021 non-null  int64
#  16  noballs           78021 non-null  int64
#  17  wicket_type       3988 non-null   object
#  18  player_dismissed  3978 non-null   object
#  19  fielder           3141 non-null   object
#  20  phase             25670 non-null  object
# dtypes: float64(1), int64(10), object(10)
# memory usage: 13.1+ MB
# None

# %%
print(df_all.describe()) # Statistics
# Out:
#             match_id        season      match_no       innings          over  \
# count   78021.000000  78021.000000  78021.000000  78021.000000  78021.000000
# mean   202410.334154   2023.754989     34.835249      1.480601      9.578133
# std       129.945738      1.316842     21.061880      0.500088      5.680486
# min    202201.000000   2022.000000      1.000000      1.000000      0.100000
# 25%    202307.000000   2023.000000     17.000000      1.000000      4.500000
# 50%    202416.000000   2024.000000     33.000000      1.000000      9.500000
# 75%    202526.000000   2025.000000     53.000000      2.000000     14.400000
# max    202636.000000   2026.000000     74.000000      4.000000     19.600000
#
#         runs_of_bat        extras          wide       legbyes          byes  \
# count  78021.000000  78021.000000  78021.000000  78021.000000  78021.000000
# mean       1.400905      0.072275      0.038913      0.012804      0.002076
# std        1.769066      0.352227      0.193388      0.112430      0.045520
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        0.000000      0.000000      0.000000      0.000000      0.000000
# 50%        1.000000      0.000000      0.000000      0.000000      0.000000
# 75%        2.000000      0.000000      0.000000      0.000000      0.000000
# max        6.000000      5.000000      1.000000      1.000000      1.000000
#
#             noballs
# count  78021.000000
# mean       0.004383
# std        0.066063
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.000000
# max        1.000000

# %%
print(df_all.columns)    # Column names
# Out:
# Index(['match_id', 'season', 'match_no', 'date', 'venue', 'batting_team',
#        'bowling_team', 'innings', 'over', 'striker', 'bowler', 'runs_of_bat',
#        'extras', 'wide', 'legbyes', 'byes', 'noballs', 'wicket_type',
#        'player_dismissed', 'fielder', 'phase'],
#       dtype='object')

# %%
print(df_all['bowler'])        # single column
# Out:
# 0          Umesh Yadav
# 1          Umesh Yadav
# 2          Umesh Yadav
# 3          Umesh Yadav
# 4          Umesh Yadav
#              ...
# 8419    Brijesh Sharma
# 8420     Nandre Burger
# 8421     Nandre Burger
# 8422     Nandre Burger
# 8423     Nandre Burger
# Name: bowler, Length: 78021, dtype: object

# %%
print(df_all[df_all['match_id'] > 4])
# Out:
#       match_id  season  match_no          date  \
# 0       202201    2022         1  Mar 26, 2022
# 1       202201    2022         1  Mar 26, 2022
# 2       202201    2022         1  Mar 26, 2022
# 3       202201    2022         1  Mar 26, 2022
# 4       202201    2022         1  Mar 26, 2022
# ...        ...     ...       ...           ...
# 8419    202636    2026        36  Apr 25, 2026
# 8420    202636    2026        36  Apr 25, 2026
# 8421    202636    2026        36  Apr 25, 2026
# 8422    202636    2026        36  Apr 25, 2026
# 8423    202636    2026        36  Apr 25, 2026
#
#                                venue batting_team bowling_team  innings  over  \
# 0           Wankhede Stadium, Mumbai          CSK          KKR        1   0.1
# 1           Wankhede Stadium, Mumbai          CSK          KKR        1   0.1
# 2           Wankhede Stadium, Mumbai          CSK          KKR        1   0.2
# 3           Wankhede Stadium, Mumbai          CSK          KKR        1   0.2
# 4           Wankhede Stadium, Mumbai          CSK          KKR        1   0.3
# ...                              ...          ...          ...      ...   ...
# 8419  Sawai Mansingh Stadium, Jaipur          SRH           RR        2  17.6
# 8420  Sawai Mansingh Stadium, Jaipur          SRH           RR        2  18.1
# 8421  Sawai Mansingh Stadium, Jaipur          SRH           RR        2  18.2
# 8422  Sawai Mansingh Stadium, Jaipur          SRH           RR        2  18.2
# 8423  Sawai Mansingh Stadium, Jaipur          SRH           RR        2  18.3
#
#                striker  ... runs_of_bat  extras  wide  legbyes  byes  noballs  \
# 0              Gaikwad  ...           0       1     0        0     0        1
# 1              Gaikwad  ...           0       0     0        0     0        0
# 2              Gaikwad  ...           0       1     1        0     0        0
# 3              Gaikwad  ...           0       0     0        0     0        0
# 4              Gaikwad  ...           0       0     0        0     0        0
# ...                ...  ...         ...     ...   ...      ...   ...      ...
# 8419  Heinrich Klaasen  ...           0       0     0        0     0        0
# 8420       Salil Arora  ...           1       0     0        0     0        0
# 8421      Aniket Verma  ...           0       1     1        0     0        0
# 8422      Aniket Verma  ...           1       0     0        0     0        0
# 8423       Salil Arora  ...           6       0     0        0     0        0
#
#       wicket_type  player_dismissed       fielder        phase
# 0             NaN               NaN           NaN          NaN
# 1             NaN               NaN           NaN          NaN
# 2             NaN               NaN           NaN          NaN
# 3             NaN               NaN           NaN          NaN
# 4          caught           Gaikwad   Nitish Rana          NaN
# ...           ...               ...           ...          ...
# 8419       caught  Heinrich Klaasen  Ravi Bishnoi  Group Stage
# 8420          NaN               NaN           NaN  Group Stage
# 8421          NaN               NaN           NaN  Group Stage
# 8422          NaN               NaN           NaN  Group Stage
# 8423          NaN               NaN           NaN  Group Stage
#
# [78021 rows x 21 columns]

# %%
print(df_all['batting_team'].value_counts())
# Out:
# batting_team
# GT      8167
# RR      8123
# RCB     7998
# LSG     7877
# CSK     7874
# SRH     7866
# MI      7865
# PBKS    7770
# DC      7404
# KKR     7077
# Name: count, dtype: int64

# %% [markdown]
# 27th april work

# %%
# Check missing values
print(df_all.isnull().sum())
# Out:
# match_id                0
# season                  0
# match_no                0
# date                    0
# venue                   0
# batting_team            0
# bowling_team            0
# innings                 0
# over                    0
# striker                 0
# bowler                  0
# runs_of_bat             0
# extras                  0
# wide                    0
# legbyes                 0
# byes                    0
# noballs                 0
# wicket_type         74033
# player_dismissed    74043
# fielder             74880
# phase               52351
# dtype: int64

# %%
df_all.fillna({
    'batsman_runs': 0,
    'extra_runs': 0,
    'is_wicket': 0
}, inplace=True)

# %%
df = df_all.drop_duplicates()

# %%
df = df_all.fillna(0)

# %%
print(df_all.columns)
# Out:
# Index(['match_id', 'season', 'match_no', 'date', 'venue', 'batting_team',
#        'bowling_team', 'innings', 'over', 'striker', 'bowler', 'runs_of_bat',
#        'extras', 'wide', 'legbyes', 'byes', 'noballs', 'wicket_type',
#        'player_dismissed', 'fielder', 'phase'],
#       dtype='object')

# %%
wides = df_all['wide']

# %%
Q1 = wides.quantile(0.25)
Q3 = wides.quantile(0.75)
IQR = Q3 - Q1

outliers = df_all[(wides < Q1 - 1.5*IQR) |
                  (wides > Q3 + 1.5*IQR)]

print(outliers)
# Out:
#       match_id  season  match_no          date  \
# 2       202201    2022         1  Mar 26, 2022
# 5       202201    2022         1  Mar 26, 2022
# 115     202201    2022         1  Mar 26, 2022
# 264     202202    2022         2  Mar 27, 2022
# 353     202202    2022         2  Mar 27, 2022
# ...        ...     ...       ...           ...
# 8340    202636    2026        36  Apr 25, 2026
# 8351    202636    2026        36  Apr 25, 2026
# 8362    202636    2026        36  Apr 25, 2026
# 8382    202636    2026        36  Apr 25, 2026
# 8421    202636    2026        36  Apr 25, 2026
#
#                                venue batting_team bowling_team  innings  over  \
# 2           Wankhede Stadium, Mumbai          CSK          KKR        1   0.2
# 5           Wankhede Stadium, Mumbai          CSK          KKR        1   0.4
# 115         Wankhede Stadium, Mumbai          CSK          KKR        1  18.4
# 264        Brabourne Stadium, Mumbai           MI           DC        1   4.4
# 353        Brabourne Stadium, Mumbai           MI           DC        1  19.2
# ...                              ...          ...          ...      ...   ...
# 8340  Sawai Mansingh Stadium, Jaipur          SRH           RR        2   5.3
# 8351  Sawai Mansingh Stadium, Jaipur          SRH           RR        2   7.1
# 8362  Sawai Mansingh Stadium, Jaipur          SRH           RR        2   8.5
# 8382  Sawai Mansingh Stadium, Jaipur          SRH           RR        2  11.6
# 8421  Sawai Mansingh Stadium, Jaipur          SRH           RR        2  18.2
#
#                striker  ... runs_of_bat  extras  wide  legbyes  byes  noballs  \
# 2              Gaikwad  ...           0       1     1        0     0        0
# 5              Uthappa  ...           0       1     1        0     0        0
# 115             Jadeja  ...           0       1     1        0     0        0
# 264              Rohit  ...           0       1     1        0     0        0
# 353        Daniel Sams  ...           0       1     1        0     0        0
# ...                ...  ...         ...     ...   ...      ...   ...      ...
# 8340      Ishan Kishan  ...           0       1     1        0     0        0
# 8351   Abhishek Sharma  ...           0       1     1        0     0        0
# 8362   Abhishek Sharma  ...           0       1     1        0     0        0
# 8382  Heinrich Klaasen  ...           0       1     1        0     0        0
# 8421      Aniket Verma  ...           0       1     1        0     0        0
#
#       wicket_type player_dismissed fielder        phase
# 2             NaN              NaN     NaN          NaN
# 5             NaN              NaN     NaN          NaN
# 115           NaN              NaN     NaN          NaN
# 264           NaN              NaN     NaN          NaN
# 353           NaN              NaN     NaN          NaN
# ...           ...              ...     ...          ...
# 8340          NaN              NaN     NaN  Group Stage
# 8351          NaN              NaN     NaN  Group Stage
# 8362          NaN              NaN     NaN  Group Stage
# 8382          NaN              NaN     NaN  Group Stage
# 8421          NaN              NaN     NaN  Group Stage
#
# [3036 rows x 21 columns]
